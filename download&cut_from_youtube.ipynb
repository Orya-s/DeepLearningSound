# %% [markdown]
# <a href="https://colab.research.google.com/github/Orya-s/DeepLearningSound/blob/master/download%26cut_from_youtube.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install pafy
# !pip install youtube_dl
# !pip install YoutubeDL
# !pip install pydub
# Out:
# ...
#      |████████████████████████████████| 1.9 MB 26.9 MB/s
# ...
# ERROR: Could not find a version that satisfies the requirement YoutubeDL (from versions: none)
# ERROR: No matching distribution found for YoutubeDL
# ...

# %%
import subprocess
import youtube_dl
import pafy
from pydub import AudioSegment
import glob
import os

def get_wav(video_url, counter):
  for file in glob.glob("/content/*.wav"):
    os.remove(file)

  try:
    video_info = youtube_dl.YoutubeDL().extract_info(
        url=video_url, download=False
    )

    options = {
        'format': 'bestaudio/best',
        'reepvideo': False,
        # 'outtmpl' : f"{video_info['title']}.wav",
        'outtmpl' : f"vid_{counter}.wav",
    }

    with youtube_dl.YoutubeDL(options) as ydl:
        ydl.download([video_info['webpage_url']])
  
  except:
      print(f"error - {video_url} , is not exist")


def cut_wav(start, end, name):
  for file in glob.glob("/content/*.wav"):
    fname = os.path.basename(file)
    newAudio = AudioSegment.from_file(file, format="mp4")
    print(newAudio)
    newAudio = newAudio[start*1000:end*1000]
    newAudio.export(f'/content/drive/MyDrive/data_wav/{name}.wav', format="wav")  # Exports to a wav file in the current path.

# get_wav("https://www.youtube.com/watch?v=5r0dWxy17C8")
# cut_wav(0,5,"roi")

# %%
def save_features_to_pkl(path_voice, i_index, i_gender, i_age): 
  window = 48000
  step = 32000 
  # dataset = load_dataset("common_voice", lang, split="test", streaming=True)
  # dataset = dataset.cast_column("audio", datasets.Audio(sampling_rate=16_000))
  # dataset_iter = iter(dataset)
  # path_voice = f'/content/drive/MyDrive/data_pkl/test/noa1.wav'
  speech_array, sampling_rate = torchaudio.load(path_voice, normalize=True)
  transform = torchaudio.transforms.Resample(sampling_rate, 16_000)

  speech_array = transform(speech_array)

  data = []
  k = 0

  print("start " + i_index)

  for index in range(2):
    # sample = next(dataset_iter)
    sample = speech_array

    array = sample[0]
    array = array[44:]

    age = i_age
    gender = i_gender

    if(gender == ""):
      break
    if(age == ""):
      break

    pointer = 0
    while pointer + window < len(array):
      curr = array[pointer:pointer+window]
      tensor_data = torch.tensor(np.array(curr))

      with torch.inference_mode():
        tensor_data = tensor_data.unsqueeze(0)
        features, _ = model(tensor_data)
        data.append({features, age, gender})

      # if (k % 51 == 1):
      #   print(index , k)
      #   print(""+ age + "," + gender)
          
      if (k % 50 == 0):
        #arr = np.array(data)
        path = f'/content/drive/MyDrive/data_pkl/vox1_pxl/vox1_{i_index}-{k}.pkl'
        with open(path,'wb') as f:
          pkl.dump(data, f)
        data =[]
      elif (len(array) / window) > 0:
        if (k % (len(array) / window) == 0):
          print("EOF!!!!!!!!!!!!!!!!!!!")
        #arr = np.array(data)
        path = f'/content/drive/MyDrive/data_pkl/vox1_pxl/vox1_{i_index}-{k}.pkl'
        with open(path,'wb') as f:
          pkl.dump(data, f)
        data =[]
      k += 1
      pointer += step

  for r_file in glob.glob("/content/drive/MyDrive/data_wav/*.wav"):
    os.remove(r_file)

# %%
id03335': 60, 'id08291': 40, 'id05441': 30, 'id02964': 30, 'id01091': 70, 'id08701': 40, 'id08234': 40, 'id01405': 50, 'id01149': 40, 'id07337': 30, 'id05091': 60, 'id06344': 80, 'id08997': 40, 'id05273': 20, 'id02312': 30, 'id05055': 30, 'id08046': 30, 'id01120': 50, 'id03713': 40, 'id05456': 30, 'id00621': 20, 'id09197': 40, 'id06547': 40, 'id02535': 20, 'id08500': 70, 'id07376': 20, 'id02540': 40, 'id00019': 40, 'id00770': 70, 'id04264': 60, 'id07076': 70, 'id06397': 40, 'id01155': 50, 'id04559': 30, 'id04906': 50, 'id00507': 50, 'id04635': 60, 'id07039': 40, 'id09055': 20, 'id04529': 30, 'id07360': 60, 'id00316': 60, 'id00875': 40, 'id01898': 60, 'id00607': 20, 'id01353': 30, 'id01160': 50, 'id00283': 30, 'id07484': 40, 'id04140': 70, 'id01244': 20, 'id02986': 50, 'id04753': 50, 'id08280': 50, 'id02823': 40, 'id06028': 40, 'id00811': 30, 'id02790': 20, 'id07947': 60, 'id04841': 40, 'id05196': 30, 'id08602': 20, 'id05257': 70, 'id09015': 30, 'id01410': 50, 'id02351': 30, 'id00690': 20, 'id06961': 20, 'id07783': 30, 'id01593': 50, 'id07395': 50, 'id06614': 70, 'id07165': 80, 'id09083': 20, 'id08790': 30, 'id01249': 30, 'id03417': 50, 'id03843': 50, 'id02914': 30, 'id01927': 40, 'id00366': 50, 'id05176': 30, 'id07283': 50, 'id01696': 50, 'id08185': 30, 'id03263': 40, 'id07229': 30, 'id04756': 40, 'id05231': 30, 'id03942': 60, 'id06237': 30, 'id02341': 40, 'id04130': 20, 'id03345': 60, 'id03467': 40, 'id08872': 30, 'id01101': 60, 'id00476': 30, 'id03841': 30, 'id07334': 60, 'id08696': 30, 'id03756': 70, 'id08501': 20, 'id07649': 30, 'id01615': 40, 'id02440': 70, 'id03014': 60, 'id02584': 30, 'id00686': 40, 'id06833': 30, 'id00562': 30, 'id04762': 30, 'id03688': 30, 'id00512': 60, 'id03318': 30, 'id02339': 50, 'id07726': 40, 'id02546': 50, 'id04713': 60, 'id04510': 40, 'id08670': 30, 'id07517': 30, 'id07320': 60, 'id00438': 30, 'id01996': 60, 'id03763': 50, 'id03961': 20, 'id00891': 60, 'id08264': 40, 'id03041': 20, 'id08421': 70, 'id01883': 40, 'id05547': 30, 'id08396': 20, 'id03248': 50, 'id03077': 50, 'id07971': 40, 'id01403': 40, 'id06927': 40, 'id03989': 40, 'id04889': 50, 'id06782': 30, 'id08906': 60, 'id08306': 40, 'id02731': 40, 'id06511': 60, 'id03861': 40, 'id06368': 20, 'id06250': 40, 'id04980': 40, 'id07007': 60, 'id06163': 60, 'id02999': 70, 'id06799': 50, 'id03929': 50, 'id05627': 40, 'id04839': 60, 'id01285': 30, 'id02075': 40, 'id07858': 40, 'id02289': 50, 'id07666': 40, 'id05432': 40, 'id00786': 30, 'id07833': 30, 'id08438': 20, 'id08689': 20, 'id04530': 40, 'id03614': 60, 'id05246': 30, 'id05664': 50, 'id02317': 40, 'id04129': 
id03953': 50, 'id00342': 20, 'id02236': 40, 'id02893': 30, 'id06791': 50, 'id01769': 20, 'id04232': 60, 'id04093': 40, 'id08669': 30, 'id06698': 80, 'id07508': 30, 'id03535': 40, 'id08686': 20, 'id04551': 30, 'id01907': 40, 'id00700': 30, 'id05583': 30, 'id06014': 30, 'id05699': 40, 'id05830': 30, 'id04484': 30, 'id03986': 40, 'id04547': 30, 'id02346': 40, 'id08764': 70, 'id04652': 60, 'id05293': 60, 'id02357': 60, 'id03524': 70, 'id07927': 60, 'id06482': 20, 'id08267': 30, 'id02006': 40, 'id08606': 50, 'id04684': 40, 'id08282': 30, 'id06963': 30, 'id05731': 60, 'id04100': 60, 'id01178': 30, 'id00773': 20, 'id01431': 50, 'id08612': 30, 'id04689': 30, 'id04647': 40, 'id03336': 20, 'id08658': 60, 'id07978': 30, 'id00231': 30, 'id00801': 20, 'id06684': 40, 'id09053': 30, 'id08748': 60, 'id06145': 60, 'id01539': 40, 'id01330': 20, 'id01827': 40, 'id02329': 30, 'id01805': 30, 'id06793': 60, 'id04490': 30, 'id07537': 30, 'id00934': 20, 'id03715': 20, 'id08982': 40, 'id04413': 40, 'id07631': 30, 'id05449': 40, 'id00418': 40, 'id03388': 40, 'id05891': 40, 'id09081': 40, 'id04422': 50, 'id00622': 30, 'id04183': 50, 'id04744': 30, 'id03757': 40, 'id01065': 30, 'id03258': 70, 'id07652': 60, 'id00842': 40, 'id04270': 20, 'id05506': 70, 'id05030': 50, 'id04642': 20, 'id04197': 60, 'id02479': 40, 'id05768': 60, 'id01756': 40, 'id03790': 40, 'id08497': 40, 'id05358': 30, 'id07099': 70, 'id06866': 40, 'id04705': 30, 'id02815': 30, 'id00355': 20, 'id04154': 50, 'id06172': 50, 'id08953': 60, 'id08648': 60, 'id05796': 20, 'id00036': 70, 'id09054': 30, 'id04219': 50, 'id07887': 30, 'id03866': 50, 'id03267': 60, 'id08904': 40, 'id07534': 50, 'id02700': 20, 'id08674': 40, 'id00434': 40, 'id01928': 40, 'id08745': 40, 'id02577': 50, 'id05877': 50, 'id01511': 40, 'id08067': 60, 'id08607': 30, 'id07785': 40, 'id08053': 30, 'id06218': 30, 'id03458': 50, 'id05959': 40, 'id02263': 60, 'id03426': 30, 'id05687': 30, 'id00680': 60, 'id04751': 40, 'id09028': 20, 'id03293': 40, 'id02432': 30, 'id01528': 30, 'id06066': 20, 'id06071': 70, 'id06092': 50, 'id05405': 30, 'id08313': 30, 'id06759': 40, 'id07917': 30, 'id06270': 20, 'id06156': 40, 'id02569': 50, 'id01611': 70, 'id06694': 60, 'id05815': 30, 'id07416': 40, 'id06676': 50, 'id00332': 30, 'id07375': 40, 'id06953': 60, 'id05551': 30, 'id04288': 40, 'id07663': 30, 'id04178': 40, 'id04188': 60, 'id01090': 20, 'id00406': 30, 'id01608': 40, 'id05939': 40, 'id00472': 60, 'id02544': 50, 'id07403': 50, 'id05207': 40, 'id00945': 40, 'id00617': 30, 'id08492': 40, 'id07015': 70, 'id06574': 30, 'id02000': 40, 'id00344': 20, 'id05229': 50, 'id07541': 60, 'id08609': 80, 'id00103': 40, 'id03689': 20, 'id01840': 50, 'id03907': 50, 'id02219': 20, 'id08545': 40, 'id07741': 60, 'id06423': 70, 'id02266': 50, 'id00816': 60, 'id00351': 20, 'id08218': 20, 'id01516': 40, 'id02017': 20, 'id00514': 30, 'id01672': 30, 'id06114': 60, 'id00347': 60, 'id05058': 40, 'id00341': 40, 'id07884': 30, 'id00232': 20, 'id07807': 20, 'id04151': 50, 'id08191': 50, 'id02490': 40, 'id00202': 50, 'id03214': 40, 'id04846': 20, 'id05370': 20, 'id00198': 40, 'id00524': 40, 'id08521': 20, 'id07733': 30, 'id07589': 30, 'id09030': 50, 'id09156': 30, 'id04826': 40, 'id01339': 20, 'id00297': 40, 'id07502': 60, 'id08676': 60, 'id07618': 50, 'id05044': 20, 'id04372': 70, 'id07466': 30, 'id03373': 40, 'id01764': 30, 'id04035': 40, 'id00242': 40, 'id03090': 50, 'id05573': 80, 'id02355': 20, 'id00650': 60, 'id07371': 30, 'id01750': 30, 'id01325': 30, 'id00049': 40, 'id09116': 60, 'id03059': 70, 'id03962': 30, 'id08294': 50, 'id04047': 20, 'id08290': 40, 'id01238': 50, 'id04704': 40, 'id06586': 60, 'id08803': 30, 'id02105': 50, 'id01115': 30, 'id06124': 30, 'id03360': 60, 'id09214': 40, 'id07736': 30, 'id09144': 50, 'id08728': 20, 'id04162': 60, 'id04821': 30, 'id00691': 40, 'id03592': 30, 'id08679': 50, 'id00289': 50, 'id05100': 70, 'id07399': 30, 'id04857': 40, 'id08113': 50, 'id08623': 50, 'id06683': 40, 'id04855': 80, 'id01298': 40, 'id09269': 50, 'id04054': 30, 'id06155': 30, 'id08012': 30, 'id02086': 60, 'id08973': 70, 'id07640': 40, 'id08839': 20, 'id03741': 30, 'id02607': 70, 'id02197': 30, 'id07077': 30, 'id01402': 70, 'id01187': 50, 'id08397': 50, 'id08130': 50, 'id01995': 30, 'id02327': 20, 'id02093': 50, 'id04716': 70, 'id05696': 60, 'id08804': 50, 'id03274': 60, 'id05847': 40, 'id06299': 40, 'id00826': 40, 'id04254': 50, 'id04897': 30, 'id08243': 50, 'id05352': 30, 'id03696': 80, 'id08520': 60, 'id02304': 60, 'id01369': 70, 'id02702': 40, 'id02331': 50, 'id06392': 50, 'id04898': 70, 'id00258': 60, 'id08231': 40, 'id03371': 30, 'id05869': 20, 'id01156': 30, 'id04512': 50, 'id09008': 40}

# %%
# !pip install datasets
# !pip install transformers

from transformers import Wav2Vec2Model
from datasets import list_datasets, load_dataset, list_metrics, load_metric
import numpy as np
import torch
import torchaudio
import requests
import matplotlib
import matplotlib.pyplot as plt
import IPython
import pickle as pkl
import datasets
# Out:
# ...
#      |████████████████████████████████| 325 kB 16.0 MB/s
# ...
#   WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProtocolError('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))': /packages/ef/ac/0eb796cf052c392f1ae586452c89ca66164f7d4f655b039ca3d06e2291af/xxhash-3.0.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl
# ...
#      |████████████████████████████████| 212 kB 25.9 MB/s
# ...
#      |████████████████████████████████| 136 kB 55.6 MB/s
# ...
#      |████████████████████████████████| 1.1 MB 42.0 MB/s
# ...
#      |████████████████████████████████| 77 kB 6.8 MB/s
# ...
#      |████████████████████████████████| 127 kB 55.6 MB/s
# ...
#      |████████████████████████████████| 94 kB 3.0 MB/s
# ...
#      |████████████████████████████████| 271 kB 48.1 MB/s
# ...
#      |████████████████████████████████| 144 kB 35.8 MB/s
# ...
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
# ...

# %%
import os
import glob
import csv
import pickle

file = open(f'/content/drive/MyDrive/data_wav/vox1_meta.csv')

csvreader = csv.reader(file)

rows = []
gender_map = {}
for row in csvreader:
    rows.append(row)

    x = str(row)
    x = x.split("'")[1]
    if((x.split("\\t"))[2] == 'm'):
      gender_map[(x.split("\\t"))[0]] = "male"
    else:
      gender_map[(x.split("\\t"))[0]] = "female"

print(gender_map)
print(len(gender_map))

txt_path = f'/content/drive/MyDrive/data_wav/vox1_dev_txt/txt'
id_arr = os.listdir(txt_path)
print(id_arr)

for id in id_arr:
    id_path = f'{txt_path}/{id}'
    video_arr = os.listdir(id_path)

    counter = 1
    for video in video_arr:
        print("/n")
        video_url = f'https://www.youtube.com/watch?v={video}'
        get_wav(video_url, counter)
        counter += 1

        video_path = f'{id_path}/{video}'
        print(video_url)

        i = 0
        for file in glob.glob(f'{video_path}/*.txt'):
            txt_name = os.path.basename(file)
            file_path = f'{file}'
            print(file_path)

            file = open(f'{file_path}')

            csvreader = csv.reader(file)
            rows = []

            for row in csvreader:
                rows.append(row)

            frame_start = str(rows[7][0]).split(" ")[0]
            frame_end = str(rows[-1][0]).split(" ")[0]

            frame_start = int(frame_start)
            frame_end = int(frame_end)

            sec_start = frame_start/25
            sec_end = frame_end/25

            ages = {10: "teens", 20 : "twenties", 30 : "thirties", 40 : "fourties", 50 : "fifties", 60 : "sixties", 70 : "seventies", 80 : "eighties", 90 : "nineties"}

            age = "sixties"
            if id_age.get(id) is not None:
              age = ages[id_age[id]]

            gender = gender_map[id]
            video_name = f'{id}_{gender}_{age}_{video}_000{i}'
            i+=1

            try:
              cut_wav(sec_start, sec_end, video_name)
            except:
              print("error-2")
    print(f"Finish all {id} files")
# Out:
# {'VoxCeleb1 ID': 'female', 'id10001': 'male', 'id10002': 'male', 'id10003': 'male', 'id10004': 'male', 'id10005': 'male', 'id10006': 'female', 'id10007': 'female', 'id10008': 'female', 'id10009': 'male', 'id10010': 'male', 'id10011': 'male', 'id10012': 'male', 'id10013': 'female', 'id10014': 'female', 'id10015': 'female', 'id10016': 'male', 'id10017': 'male', 'id10018': 'male', 'id10019': 'male', 'id10020': 'male', 'id10021': 'male', 'id10022': 'male', 'id10023': 'male', 'id10024': 'female', 'id10025': 'male', 'id10026': 'female', 'id10027': 'female', 'id10028': 'male', 'id10029': 'male', 'id10030': 'female', 'id10031': 'male', 'id10032': 'female', 'id10033': 'female', 'id10034': 'female', 'id10035': 'female', 'id10036': 'female', 'id10037': 'female', 'id10038': 'female', 'id10039': 'female', 'id10040': 'female', 'id10041': 'female', 'id10042': 'male', 'id10043': 'female', 'id10044': 'female', 'id10045': 'male', 'id10046': 'female', 'id10047': 'female', 'id10048': 'female', 'id10049'
# ...
